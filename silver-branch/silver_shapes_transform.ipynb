# %%
dbutils.fs.ls("abfss://bronze@grtadlsdev.dfs.core.windows.net")

df = spark.table("bronze.shapes")
display(df.limit(50))

# %%
spark.catalog.listTables("silver")

# %%
# %sql
create schema if not exists silver

# %%
df.write.format("delta").mode("overwrite").option("overwriteSchema" ,"true").saveAsTable("silver.shapes")

silver_path = "abfss://silver@grtadlsdev.dfs.core.windows.net/shapes"
df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(silver_path)

# %%
spark.catalog.listTables("silver")
